# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulazeezv2089/CSA1702/blob/main/EXP%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sort words in a sentence alphabetically

sentence = input("Enter a sentence: ")

words = sentence.split()
words.sort()

print("Alphabetical Order:")
print(" ".join(words))
# Out:
# Enter a sentence:  Python is easy and powerful
# Alphabetical Order:
# Python and easy is powerful
